# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import *
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import to_categorical
from sklearn.model_selection import GridSearchCV
import pprint
pp = pprint.PrettyPrinter(indent = 4)

# %% [markdown]
# # Load Dataset

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
y_test.shape
# Out:
# (10000,)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# # visualizing the dataset

# %%
for i in range(25):
    # define subplot
    plt.subplot(5, 5, i+1)
    # plot raw pixel data
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
# show the figure
plt.show()

# %%
x_train =x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# %%
model = tf.keras.Sequential()

# Must define the input shape in the first layer of the neural network
model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=2, padding='same', activation='relu', input_shape=(28,28,1)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model.add(tf.keras.layers.Dropout(0.3))

model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model.add(tf.keras.layers.Dropout(0.3))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 28, 28, 64)        320
#
#  max_pooling2d_4 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 14, 14, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 32)        8224
#
#  max_pooling2d_5 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  dropout_7 (Dropout)         (None, 7, 7, 32)          0
#
#  flatten_5 (Flatten)         (None, 1568)              0
#
#  dense_10 (Dense)            (None, 256)               401664
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_11 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 412,778
# Trainable params: 412,778
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train,y_train, epochs=20, batch_size=512, shuffle=True, validation_split=0.1)
# Out:
# Epoch 1/20
# 106/106 [==============================] - 98s 913ms/step - loss: 0.8581 - accuracy: 0.6819 - val_loss: 0.4811 - val_accuracy: 0.8253
# Epoch 2/20
# 106/106 [==============================] - 80s 754ms/step - loss: 0.5082 - accuracy: 0.8148 - val_loss: 0.4095 - val_accuracy: 0.8523
# Epoch 3/20
# 106/106 [==============================] - 80s 757ms/step - loss: 0.4462 - accuracy: 0.8369 - val_loss: 0.3644 - val_accuracy: 0.8648
# Epoch 4/20
# 106/106 [==============================] - 78s 730ms/step - loss: 0.4078 - accuracy: 0.8535 - val_loss: 0.3403 - val_accuracy: 0.8773
# Epoch 5/20
# 106/106 [==============================] - 80s 750ms/step - loss: 0.3843 - accuracy: 0.8611 - val_loss: 0.3205 - val_accuracy: 0.8840
# Epoch 6/20
# 106/106 [==============================] - 87s 805ms/step - loss: 0.3688 - accuracy: 0.8662 - val_loss: 0.3102 - val_accuracy: 0.8850
# Epoch 7/20
# 106/106 [==============================] - 78s 741ms/step - loss: 0.3559 - accuracy: 0.8700 - val_loss: 0.3083 - val_accuracy: 0.8878
# Epoch 8/20
# 106/106 [==============================] - 79s 745ms/step - loss: 0.3432 - accuracy: 0.8746 - val_loss: 0.2898 - val_accuracy: 0.8943
# Epoch 9/20
# 106/106 [==============================] - 80s 759ms/step - loss: 0.3287 - accuracy: 0.8799 - val_loss: 0.2833 - val_accuracy: 0.8978
# Epoch 10/20
# 106/106 [==============================] - 78s 740ms/step - loss: 0.3211 - accuracy: 0.8832 - val_loss: 0.2811 - val_accuracy: 0.8952
# Epoch 11/20
# 106/106 [==============================] - 80s 752ms/step - loss: 0.3169 - accuracy: 0.8826 - val_loss: 0.2728 - val_accuracy: 0.9017
# Epoch 12/20
# 106/106 [==============================] - 78s 732ms/step - loss: 0.3068 - accuracy: 0.8864 - val_loss: 0.2685 - val_accuracy: 0.9015
# Epoch 13/20
# 106/106 [==============================] - 87s 817ms/step - loss: 0.3038 - accuracy: 0.8870 - val_loss: 0.2633 - val_accuracy: 0.9027
# Epoch 14/20
# 106/106 [==============================] - 78s 739ms/step - loss: 0.2960 - accuracy: 0.8899 - val_loss: 0.2695 - val_accuracy: 0.9012
# Epoch 15/20
# 106/106 [==============================] - 79s 747ms/step - loss: 0.2921 - accuracy: 0.8922 - val_loss: 0.2568 - val_accuracy: 0.9048
# Epoch 16/20
# 106/106 [==============================] - 78s 737ms/step - loss: 0.2851 - accuracy: 0.8948 - val_loss: 0.2553 - val_accuracy: 0.9073
# Epoch 17/20
# 106/106 [==============================] - 81s 763ms/step - loss: 0.2773 - accuracy: 0.8981 - val_loss: 0.2467 - val_accuracy: 0.9092
# Epoch 18/20
# 106/106 [==============================] - 78s 737ms/step - loss: 0.2804 - accuracy: 0.8964 - val_loss: 0.2479 - val_accuracy: 0.9072
# Epoch 19/20
# 106/106 [==============================] - 79s 749ms/step - loss: 0.2735 - accuracy: 0.8984 - val_loss: 0.2464 - val_accuracy: 0.9082
# Epoch 20/20
# 106/106 [==============================] - 79s 749ms/step - loss: 0.2701 - accuracy: 0.8997 - val_loss: 0.2475 - val_accuracy: 0.9078

# %%
test_loss, test_accuracy = model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 4s 13ms/step - loss: 0.2588 - accuracy: 0.9049

# %%
print(test_accuracy)
# Out:
# 0.9049000144004822

# %%
# !pip install -q -U keras-tuner

# %%
import keras_tuner as kt

# %%
def model_builder(hp):
  model = keras.Sequential()
  model.add(keras.layers.Flatten(input_shape=(28, 28)))

  # Tune the number of units in the first Dense layer
  # Choose an optimal value between 32-512
  hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
  model.add(keras.layers.Dense(units=hp_units, activation='relu'))
  model.add(keras.layers.Dense(10))

  # Tune the learning rate for the optimizer
  # Choose an optimal value from 0.01, 0.001, or 0.0001
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

  model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])

  return model

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_accuracy',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt')

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(x_train,y_train, epochs=50, validation_split=0.2, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 416 and the optimal learning rate for the optimizer
# is 0.001.

# %%
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
model = tuner.hypermodel.build(best_hps)
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2)

val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Epoch 1/50
# 1500/1500 [==============================] - 16s 10ms/step - loss: 0.4920 - accuracy: 0.8253 - val_loss: 0.3965 - val_accuracy: 0.8551
# Epoch 2/50
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.3696 - accuracy: 0.8647 - val_loss: 0.3610 - val_accuracy: 0.8688
# Epoch 3/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.3309 - accuracy: 0.8791 - val_loss: 0.3557 - val_accuracy: 0.8675
# Epoch 4/50
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.3052 - accuracy: 0.8874 - val_loss: 0.3165 - val_accuracy: 0.8853
# Epoch 5/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2862 - accuracy: 0.8942 - val_loss: 0.3247 - val_accuracy: 0.8865
# Epoch 6/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2715 - accuracy: 0.8990 - val_loss: 0.3251 - val_accuracy: 0.8850
# Epoch 7/50
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.2583 - accuracy: 0.9042 - val_loss: 0.3102 - val_accuracy: 0.8881
# Epoch 8/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2452 - accuracy: 0.9085 - val_loss: 0.3298 - val_accuracy: 0.8859
# Epoch 9/50
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.2326 - accuracy: 0.9134 - val_loss: 0.3210 - val_accuracy: 0.8888
# Epoch 10/50
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.2273 - accuracy: 0.9147 - val_loss: 0.3091 - val_accuracy: 0.8952
# Epoch 11/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2175 - accuracy: 0.9176 - val_loss: 0.3262 - val_accuracy: 0.8893
# Epoch 12/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2063 - accuracy: 0.9218 - val_loss: 0.3160 - val_accuracy: 0.8905
# Epoch 13/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2011 - accuracy: 0.9249 - val_loss: 0.3407 - val_accuracy: 0.8873
# Epoch 14/50
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.1955 - accuracy: 0.9258 - val_loss: 0.3182 - val_accuracy: 0.8926
# Epoch 15/50
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.1870 - accuracy: 0.9289 - val_loss: 0.3204 - val_accuracy: 0.8928
# Epoch 16/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1800 - accuracy: 0.9329 - val_loss: 0.3172 - val_accuracy: 0.8939
# Epoch 17/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1742 - accuracy: 0.9349 - val_loss: 0.3413 - val_accuracy: 0.8888
# Epoch 18/50
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.1692 - accuracy: 0.9377 - val_loss: 0.3350 - val_accuracy: 0.8955
# Epoch 19/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1602 - accuracy: 0.9404 - val_loss: 0.3403 - val_accuracy: 0.8971
# Epoch 20/50
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.1568 - accuracy: 0.9420 - val_loss: 0.3569 - val_accuracy: 0.8933
# Epoch 21/50
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.1542 - accuracy: 0.9417 - val_loss: 0.3480 - val_accuracy: 0.8957
# Epoch 22/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1481 - accuracy: 0.9448 - val_loss: 0.3707 - val_accuracy: 0.8912
# Epoch 23/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1416 - accuracy: 0.9465 - val_loss: 0.3491 - val_accuracy: 0.8958
# Epoch 24/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1403 - accuracy: 0.9481 - val_loss: 0.4040 - val_accuracy: 0.8910
# Epoch 25/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1342 - accuracy: 0.9498 - val_loss: 0.3682 - val_accuracy: 0.8926
# Epoch 26/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1307 - accuracy: 0.9503 - val_loss: 0.3668 - val_accuracy: 0.8953
# Epoch 27/50
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.1298 - accuracy: 0.9509 - val_loss: 0.3753 - val_accuracy: 0.8953
# Epoch 28/50
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.1258 - accuracy: 0.9529 - val_loss: 0.3714 - val_accuracy: 0.8978
# Epoch 29/50
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.1185 - accuracy: 0.9555 - val_loss: 0.4033 - val_accuracy: 0.8904
# Epoch 30/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1217 - accuracy: 0.9535 - val_loss: 0.4151 - val_accuracy: 0.8896
# Epoch 31/50
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.1119 - accuracy: 0.9572 - val_loss: 0.4066 - val_accuracy: 0.8915
# Epoch 32/50
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.1114 - accuracy: 0.9579 - val_loss: 0.4544 - val_accuracy: 0.8889
# Epoch 33/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1115 - accuracy: 0.9581 - val_loss: 0.4262 - val_accuracy: 0.8938
# Epoch 34/50
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.1082 - accuracy: 0.9593 - val_loss: 0.4236 - val_accuracy: 0.8947
# Epoch 35/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1019 - accuracy: 0.9623 - val_loss: 0.4218 - val_accuracy: 0.8979
# Epoch 36/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1020 - accuracy: 0.9615 - val_loss: 0.4387 - val_accuracy: 0.8927
# Epoch 37/50
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.1013 - accuracy: 0.9619 - val_loss: 0.4417 - val_accuracy: 0.8914
# Epoch 38/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0967 - accuracy: 0.9634 - val_loss: 0.4544 - val_accuracy: 0.8942
# Epoch 39/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0937 - accuracy: 0.9647 - val_loss: 0.4735 - val_accuracy: 0.8911
# Epoch 40/50
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0945 - accuracy: 0.9655 - val_loss: 0.4692 - val_accuracy: 0.8925
# Epoch 41/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0873 - accuracy: 0.9671 - val_loss: 0.4590 - val_accuracy: 0.8953
# Epoch 42/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0905 - accuracy: 0.9659 - val_loss: 0.4626 - val_accuracy: 0.8914
# Epoch 43/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0869 - accuracy: 0.9680 - val_loss: 0.4846 - val_accuracy: 0.8863
# Epoch 44/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0855 - accuracy: 0.9678 - val_loss: 0.4706 - val_accuracy: 0.8945
# Epoch 45/50
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0862 - accuracy: 0.9679 - val_loss: 0.4976 - val_accuracy: 0.8973
# Epoch 46/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0811 - accuracy: 0.9695 - val_loss: 0.4950 - val_accuracy: 0.8932
# Epoch 47/50
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0822 - accuracy: 0.9683 - val_loss: 0.5147 - val_accuracy: 0.8957
# Epoch 48/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0780 - accuracy: 0.9701 - val_loss: 0.5325 - val_accuracy: 0.8873
# Epoch 49/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0821 - accuracy: 0.9688 - val_loss: 0.5003 - val_accuracy: 0.8921
# Epoch 50/50
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0783 - accuracy: 0.9703 - val_loss: 0.5482 - val_accuracy: 0.8942
# Best epoch: 35

# %%
hypermodel = tuner.hypermodel.build(best_hps)

# Retrain the model
hypermodel.fit(x_train, y_train, epochs=best_epoch, validation_split=0.2)
# Out:
# Epoch 1/35
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.4945 - accuracy: 0.8248 - val_loss: 0.4163 - val_accuracy: 0.8466
# Epoch 2/35
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.3733 - accuracy: 0.8636 - val_loss: 0.3793 - val_accuracy: 0.8620
# Epoch 3/35
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.3316 - accuracy: 0.8789 - val_loss: 0.3416 - val_accuracy: 0.8768
# Epoch 4/35
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.3073 - accuracy: 0.8858 - val_loss: 0.3399 - val_accuracy: 0.8770
# Epoch 5/35
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2890 - accuracy: 0.8924 - val_loss: 0.3509 - val_accuracy: 0.8741
# Epoch 6/35
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2724 - accuracy: 0.8983 - val_loss: 0.3201 - val_accuracy: 0.8830
# Epoch 7/35
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.2582 - accuracy: 0.9046 - val_loss: 0.3339 - val_accuracy: 0.8812
# Epoch 8/35
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2441 - accuracy: 0.9093 - val_loss: 0.3254 - val_accuracy: 0.8820
# Epoch 9/35
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2367 - accuracy: 0.9124 - val_loss: 0.3239 - val_accuracy: 0.8863
# Epoch 10/35
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2267 - accuracy: 0.9153 - val_loss: 0.3410 - val_accuracy: 0.8807
# Epoch 11/35
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.2158 - accuracy: 0.9193 - val_loss: 0.3234 - val_accuracy: 0.8880
# Epoch 12/35
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2101 - accuracy: 0.9210 - val_loss: 0.3259 - val_accuracy: 0.8832
# Epoch 13/35
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2034 - accuracy: 0.9241 - val_loss: 0.3199 - val_accuracy: 0.8919
# Epoch 14/35
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1924 - accuracy: 0.9274 - val_loss: 0.3286 - val_accuracy: 0.8900
# Epoch 15/35
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1849 - accuracy: 0.9296 - val_loss: 0.3360 - val_accuracy: 0.8906
# Epoch 16/35
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.1825 - accuracy: 0.9314 - val_loss: 0.3264 - val_accuracy: 0.8931
# Epoch 17/35
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.1752 - accuracy: 0.9344 - val_loss: 0.3445 - val_accuracy: 0.8887
# Epoch 18/35
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.1691 - accuracy: 0.9365 - val_loss: 0.3508 - val_accuracy: 0.8861
# Epoch 19/35
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1617 - accuracy: 0.9394 - val_loss: 0.3410 - val_accuracy: 0.8931
# Epoch 20/35
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1590 - accuracy: 0.9399 - val_loss: 0.3452 - val_accuracy: 0.8946
# Epoch 21/35
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1532 - accuracy: 0.9431 - val_loss: 0.3411 - val_accuracy: 0.8941
# Epoch 22/35
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1494 - accuracy: 0.9434 - val_loss: 0.3803 - val_accuracy: 0.8870
# Epoch 23/35
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1434 - accuracy: 0.9462 - val_loss: 0.3547 - val_accuracy: 0.8976
# Epoch 24/35
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1407 - accuracy: 0.9464 - val_loss: 0.3949 - val_accuracy: 0.8900
# Epoch 25/35
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.1361 - accuracy: 0.9489 - val_loss: 0.3796 - val_accuracy: 0.8921
# Epoch 26/35
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1338 - accuracy: 0.9489 - val_loss: 0.3962 - val_accuracy: 0.8892
# Epoch 27/35
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1268 - accuracy: 0.9523 - val_loss: 0.3627 - val_accuracy: 0.8959
# Epoch 28/35
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1255 - accuracy: 0.9528 - val_loss: 0.3927 - val_accuracy: 0.8930
# Epoch 29/35
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1231 - accuracy: 0.9547 - val_loss: 0.3870 - val_accuracy: 0.8975
# Epoch 30/35
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.1173 - accuracy: 0.9554 - val_loss: 0.3981 - val_accuracy: 0.8943
# Epoch 31/35
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1164 - accuracy: 0.9568 - val_loss: 0.3971 - val_accuracy: 0.8942
# Epoch 32/35
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1123 - accuracy: 0.9586 - val_loss: 0.3999 - val_accuracy: 0.8947
# Epoch 33/35
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.1116 - accuracy: 0.9582 - val_loss: 0.4465 - val_accuracy: 0.8878
# Epoch 34/35
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1076 - accuracy: 0.9594 - val_loss: 0.4049 - val_accuracy: 0.8961
# Epoch 35/35
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1025 - accuracy: 0.9604 - val_loss: 0.4150 - val_accuracy: 0.8942

# %%
eval_result = hypermodel.evaluate(x_test, y_test)
print("[test loss, test accuracy]:", eval_result)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4707 - accuracy: 0.8882
# [test loss, test accuracy]: [0.4706501066684723, 0.8881999850273132]

# %%
#Model Prediction

predict_x=model.predict(x_test)
y_pred=np.argmax(predict_x,axis=1)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
for i in range(0,10):
    print(y_pred[i], y_test[i]) #predicted and actual class
# Out:
# 9 9
# 2 2
# 1 1
# 1 1
# 6 6
# 1 1
# 4 4
# 6 6
# 5 5
# 7 7

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cn = confusion_matrix(y_test, y_pred)
print(cn)
# Out:
# [[846   2  12  17   6   1 107   0   9   0]
#  [  3 973   2  13   5   0   4   0   0   0]
#  [ 17   1 726   7 132   1 111   0   5   0]
#  [ 21   6   8 877  54   0  28   0   6   0]
#  [  0   0  47  16 876   0  59   0   2   0]
#  [  0   0   0   1   0 955   0  27   2  15]
#  [109   0  46  34  74   0 729   0   8   0]
#  [  0   0   0   0   0   9   0 976   1  14]
#  [  6   0   4   5   2   5   5   3 970   0]
#  [  0   0   0   0   0   8   1  42   0 949]]

# %%
acc_cm = accuracy_score(y_test, y_pred)
print(acc_cm)
# Out:
# 0.8877

# %%
from sklearn.metrics  import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85      1000
#            1       0.99      0.97      0.98      1000
#            2       0.86      0.73      0.79      1000
#            3       0.90      0.88      0.89      1000
#            4       0.76      0.88      0.82      1000
#            5       0.98      0.95      0.97      1000
#            6       0.70      0.73      0.71      1000
#            7       0.93      0.98      0.95      1000
#            8       0.97      0.97      0.97      1000
#            9       0.97      0.95      0.96      1000
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000
